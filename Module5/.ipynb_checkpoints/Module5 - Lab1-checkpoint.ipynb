# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module5- Lab1

# %% [markdown]
# Start by importing whatever you need to import in order to make this lab work:

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %% [markdown]
# ### How to Get The Dataset

# %% [markdown]
# 1. Open up the City of Chicago's [Open Data | Crimes](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2) page.
# 1. In the `Primary Type` column, click on the `Menu` button next to the info button, and select `Filter This Column`. It might take a second for the filter option to show up, since it has to load the entire list first.
# 1. Scroll down to `GAMBLING`
# 1. Click the light blue `Export` button next to the `Filter` button, and select `Download As CSV`

# %% [markdown]
# Now that you have th dataset stored as a CSV, load it up being careful to double check headers, as per usual:

# %%
df = pd.read_csv('Datasets/Crimes_-_2001_to_present.csv')
df
# Out:
#              ID Case Number                    Date  \
# 0      10002677    HY191890  03/20/2015 01:13:00 PM
# 1      10003802    HY193541  03/21/2015 06:45:00 PM
# 2      10003937    HY193663  03/21/2015 07:55:00 PM
# 3      10004429    HY194332  03/22/2015 01:57:00 PM
# 4      10005837    HY195964  03/23/2015 08:40:00 PM
# 5      10011726    HY200956  03/27/2015 09:10:00 AM
# 6      10012328    HY201988  03/28/2015 06:45:00 PM
# 7      10014339    HY203868  03/30/2015 02:19:00 PM
# 8      10016050    HY205430  03/31/2015 07:05:00 PM
# 9      10017499    HY206880  04/01/2015 08:00:00 PM
# 10     10017527    HY206917  04/01/2015 08:26:00 PM
# 11     10019991    HY209099  04/03/2015 02:40:00 PM
# 12     10021717    HY211521  04/05/2015 06:15:00 PM
# 13     10021787    HY211542  04/05/2015 06:10:00 PM
# 14     10021905    HY211720  04/05/2015 09:12:00 PM
# 15     10022799    HY212450  04/06/2015 03:15:00 PM
# 16     10022987    HY212632  04/06/2015 05:19:00 PM
# 17     10023151    HY212920  04/06/2015 08:06:00 PM
# 18     10025150    HY214606  04/08/2015 02:18:00 PM
# 19     10026553    HY215974  04/09/2015 05:15:00 PM
# 20     10026845    HY216352  04/09/2015 10:51:00 PM
# 21     10027287    HY216642  04/10/2015 10:35:00 AM
# 22     10027404    HY216736  04/10/2015 11:20:00 AM
# 23     10029260    HY219186  04/12/2015 01:00:00 PM
# 24     10029300    HY219250  04/12/2015 01:31:00 PM
# 25     10029364    HY219341  04/12/2015 03:20:00 PM
# 26     10032340    HY222187  04/14/2015 07:20:00 PM
# 27     10032473    HY222316  04/14/2015 07:40:00 PM
# 28     10034039    HY223517  04/15/2015 08:30:00 PM
# 29     10034124    HY223598  04/15/2015 09:45:00 PM
# ...         ...         ...                     ...
# 14382  11438310    JB424730  09/06/2018 01:17:00 PM
# 14383  11445470    JB434474  09/13/2018 10:52:00 PM
# 14384  11447874    JB437814  09/16/2018 12:00:00 PM
# 14385  11447987    JB437942  09/16/2018 01:30:00 PM
# 14386  11449784    JB440296  09/18/2018 08:57:00 AM
# 14387  11449849    JB440329  09/18/2018 09:15:00 AM
# 14388  11450474    JB441102  09/18/2018 06:22:00 PM
# 14389  11452837    JB444110  09/20/2018 07:44:00 PM
# 28                         024XX W 66TH ST  1661     GAMBLING
# 29                         053XX W OHIO ST  1661     GAMBLING
# ...                                    ...   ...          ...
# 14382              023XX W WASHINGTON BLVD  1661     GAMBLING
# 14383                   038XX W GLADYS AVE  1661     GAMBLING
# 14384                    0000X S LOTUS AVE  1661     GAMBLING
# 14385                 033XX W VAN BUREN ST  1661     GAMBLING
# 14386                 033XX W VAN BUREN ST  1661     GAMBLING
# 14387                 034XX W LEXINGTON ST  1661     GAMBLING
# 14388                 056XX S MICHIGAN AVE  1661     GAMBLING
# 14389                  066XX S LANGLEY AVE  1661     GAMBLING
# 14390               006XX N LEAMINGTON AVE  1661     GAMBLING
# 14391                 063XX S ARTESIAN AVE  1661     GAMBLING
# 14392                  037XX W CHICAGO AVE  1661     GAMBLING
# 14393                   005XX N KEDZIE AVE  1661     GAMBLING
# 14394                 033XX W VAN BUREN ST  1661     GAMBLING
# 14395                 008XX N ST LOUIS AVE  1661     GAMBLING
# 14396                   062XX S SEELEY AVE  1661     GAMBLING
# 14397               006XX N LEAMINGTON AVE  1661     GAMBLING
# 14398                    011XX N MASON AVE  1661     GAMBLING
# 14399                    039XX W THOMAS ST  1661     GAMBLING
# 14400                    031XX W MONROE ST  1661     GAMBLING
# 14401                 033XX W VAN BUREN ST  1661     GAMBLING
# 14402                  037XX W CHICAGO AVE  1661     GAMBLING
# 14403                     024XX S STATE ST  1661     GAMBLING
# 14404                 023XX S WENTWORTH AV  1651     GAMBLING
# 14405                        0000X W 24 ST  1661     GAMBLING
# 14406                     029XX S STATE ST  1661     GAMBLING
# 14407                 023XX S WENTWORTH AV  1651     GAMBLING
# 14408                 002XX W ALEXANDER ST  1651     GAMBLING
# 14409                  027XX S DEARBORN ST  1661     GAMBLING
# 14410  030XX S DR MARTIN LUTHER KING JR DR  1661     GAMBLING
# 14411                  078XX S WESTERN AVE  1661     GAMBLING
#
#                  Description            Location Description  Arrest  \
# 0                  GAME/DICE                          STREET    True
# 1                  GAME/DICE                        SIDEWALK    True
# 2      GAME/AMUSEMENT DEVICE              SMALL RETAIL STORE    True
# 3                  GAME/DICE                        SIDEWALK    True
# 4                  GAME/DICE  PARKING LOT/GARAGE(NON.RESID.)    True
# 5      GAME/AMUSEMENT DEVICE                           OTHER    True
# 6                  GAME/DICE                        SIDEWALK    True
# 7                  GAME/DICE                        SIDEWALK    True
# 8                  GAME/DICE                           ALLEY    True
# 9                  GAME/DICE                          STREET    True
# 10                 GAME/DICE                           ALLEY    True
# 11                 GAME/DICE                        SIDEWALK    True
# 12                 GAME/DICE                        SIDEWALK    True
# 13                 GAME/DICE                           ALLEY    True
# 14                 GAME/DICE         RESIDENCE PORCH/HALLWAY    True
# 15                 GAME/DICE                     GAS STATION    True
# 16                 GAME/DICE                       RESIDENCE    True
# 17                 GAME/DICE                        SIDEWALK    True
# 18                 GAME/DICE                        SIDEWALK    True
# 19                 GAME/DICE                        SIDEWALK    True
# 20                 GAME/DICE                       APARTMENT    True
# 21                 GAME/DICE                        SIDEWALK    True
# 22                 GAME/DICE  PARKING LOT/GARAGE(NON.RESID.)    True
# 23                 GAME/DICE  PARKING LOT/GARAGE(NON.RESID.)    True
# 24                 GAME/DICE                        SIDEWALK    True
# 25                 GAME/DICE                        SIDEWALK    True
# 26                 GAME/DICE                        SIDEWALK    True
# 27                 GAME/DICE                        SIDEWALK    True
# 28                 GAME/DICE                           OTHER    True
# 29                 GAME/DICE                          STREET    True
# ...                      ...                             ...     ...
# 14382              GAME/DICE                        SIDEWALK    True
# 14383              GAME/DICE                        SIDEWALK    True
# 14384              GAME/DICE                        SIDEWALK    True
# 14385              GAME/DICE                        SIDEWALK    True
# 14386              GAME/DICE                        SIDEWALK    True
# 14387              GAME/DICE                        SIDEWALK    True
# 14388              GAME/DICE   RESIDENTIAL YARD (FRONT/BACK)    True
# 14389              GAME/DICE                        SIDEWALK    True
# 14390              GAME/DICE                        SIDEWALK    True
# 14391              GAME/DICE   RESIDENTIAL YARD (FRONT/BACK)    True
# 14392              GAME/DICE                        SIDEWALK    True
# 14393              GAME/DICE                        SIDEWALK    True
# 14394              GAME/DICE                          STREET    True
# 14395              GAME/DICE                        SIDEWALK    True
# 14396              GAME/DICE                        SIDEWALK    True
# 14397              GAME/DICE                        SIDEWALK    True
# 14398              GAME/DICE                        SIDEWALK    True
# 14399              GAME/DICE                        SIDEWALK    True
# 14400              GAME/DICE                          STREET    True
# 14401              GAME/DICE                        SIDEWALK    True
# 14402              GAME/DICE                           ALLEY    True
# 14403              GAME/DICE  CHA HALLWAY/STAIRWELL/ELEVATOR    True
# 14404             GAME/CARDS                       RESIDENCE    True
# 14405              GAME/DICE  CHA HALLWAY/STAIRWELL/ELEVATOR    True
# 14406              GAME/DICE         CHA PARKING LOT/GROUNDS    True
# 14407             GAME/CARDS                       APARTMENT    True
# 14408             GAME/CARDS                           OTHER    True
# 14409              GAME/DICE  CHA HALLWAY/STAIRWELL/ELEVATOR    True
# 14410              GAME/DICE                          STREET    True
# 14411              GAME/DICE                    CTA BUS STOP    True
#
#        Domestic              ...                Ward  Community Area  \
# 0         False              ...                17.0            67.0
# 1         False              ...                28.0            26.0
# 2         False              ...                39.0            14.0
# 3         False              ...                24.0            29.0
# 4         False              ...                24.0            29.0
# 5         False              ...                36.0            17.0
# 6         False              ...                27.0            23.0
# 7         False              ...                24.0            29.0
# 8         False              ...                20.0            68.0
# 9         False              ...                24.0            25.0
# 10        False              ...                15.0            67.0
# 11        False              ...                 3.0            61.0
# 12        False              ...                28.0            26.0
# 13        False              ...                21.0            71.0
# 14        False              ...                 7.0            43.0
# 15        False              ...                28.0            25.0
# 16        False              ...                20.0            40.0
# 17        False              ...                 3.0            61.0
# 18        False              ...                17.0            68.0
# 19        False              ...                17.0            68.0
# 20        False              ...                21.0            71.0
# 14397  41.891982 -87.754270  (41.891981518, -87.754270004)
# 14398  41.901095 -87.774119  (41.901094731, -87.774119002)
# 14399  41.900865 -87.724201   (41.900865488, -87.72420104)
# 14400  41.879672 -87.703916   (41.879672076, -87.70391588)
# 14401  41.875458 -87.710144   (41.875457946, -87.71014426)
# 14402  41.895422 -87.720293  (41.895422074, -87.720293303)
# 14403  41.848099 -87.626963   (41.84809924, -87.626962834)
# 14404  41.849760 -87.631944  (41.849759853, -87.631943583)
# 14405  41.849221 -87.628573   (41.849220554, -87.62857278)
# 14406  41.840983 -87.626850  (41.840982682, -87.626850277)
# 14407  41.849760 -87.631944  (41.849759853, -87.631943583)
# 14408  41.851439 -87.632821  (41.851439204, -87.632820826)
# 14409  41.844000 -87.628443  (41.844000177, -87.628442902)
# 14410  41.839816 -87.617516  (41.839816207, -87.617516172)
# 14411  41.751065 -87.682874  (41.751065032, -87.682873958)
#
# [14412 rows x 22 columns]

# %% [markdown]
# Get rid of any _rows_ that have nans in them:

# %%
df = df.dropna(axis=0)

# %% [markdown]
# Display the `dtypes` of your dset:

# %%
df.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                      int64
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                  int64
# Ward                    float64
# Community Area          float64
# FBI Code                  int64
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %% [markdown]
# Coerce the `Date` feature (which is currently a string object) into real date, and confirm by displaying the `dtypes` again. This might be a slow executing process...

# %%
df.Date = pd.to_datetime(df.Date, errors = 'coerce')
df.dtypes
# Out:
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# ID                               int64
# Case Number                     object
# Date                    datetime64[ns]
# Block                           object
# IUCR                             int64
# Primary Type                    object
# Description                     object
# Location Description            object
# Arrest                            bool
# Domestic                          bool
# Beat                             int64
# District                         int64
# Ward                           float64
# Community Area                 float64
# FBI Code                         int64
# X Coordinate                   float64
# Y Coordinate                   float64
# Year                             int64
# Updated On                      object
# Latitude                       float64
# Longitude                      float64
# Location                        object
# dtype: object

# %%
def doKMeans(df):
    # Let's plot your data with a '.' marker, a 0.3 alpha at the Longitude,
    # and Latitude locations in your dataset. Longitude = x, Latitude = y
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.scatter(df.Longitude, df.Latitude, marker='.', alpha=0.3)

    
    # TODO: Filter `df` using indexing so it only contains Longitude and Latitude,
    # since the remaining columns aren't really applicable for this lab:
    #
    df = df.loc[:,['Longitude', 'Latitude']]


    # TODO: Use K-Means to try and find seven cluster centers in this df.
    # Be sure to name your kmeans model `model` so that the printing works.
    #
    model = KMeans(n_clusters=7)
    model.fit(df)
    

    # Now we can print and plot the centroids:
    centroids = model.cluster_centers_
    print(centroids)
    ax.scatter(centroids[:,0], centroids[:,1], marker='x', c='red', alpha=0.5, linewidths=3, s=169)
    plt.show()

# %%
# Print & Plot your data
doKMeans(df)
# Out:
# [[-87.7097369   41.87815651]
#  [-87.63110893  41.69674023]
#  [-87.66486774  41.77277941]
#  [-87.61939123  41.80290526]
#  [-87.75690897  41.89340281]
#  [-87.6850217   41.98174333]
#  [-87.58243845  41.75230925]]

# %% [markdown]
# Filter out the data so that it only contains samples that have a `Date > '2011-01-01'`, using indexing. Then, in a new figure, plot the crime incidents, as well as a new K-Means run's centroids.

# %%
df = df[df.Date>'2011-01-01']

# %%
# Print & Plot your data
doKMeans(df)
# Out:
# [[-87.61900068  41.79186526]
#  [-87.71102142  41.87572966]
#  [-87.58049905  41.75048186]
#  [-87.66502778  41.77545653]
#  [-87.6342661   41.70530004]
#  [-87.75510054  41.89012282]
#  [-87.6868321   41.98345852]]
