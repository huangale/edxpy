# %%
# %matplotlib notebook 

import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %%
plt.style.use('ggplot') # Look Pretty

# %%
student_dataset = pd.read_csv("D:\misc\edx\Programming with Python for Data Science\DAT210x\Module3\Datasets\students.data", index_col=0)

# %%
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Final Grade')
ax.set_ylabel('First Grade')
ax.set_zlabel('Daily Alcohol')
ax.scatter(student_dataset.G1, student_dataset.G3, student_dataset['Dalc'], c='r', marker='.')
# won't need plt.show() with %matplotlib notebook before imports
# Out:
# <img src="data:image/png;base64,..." width="640">
