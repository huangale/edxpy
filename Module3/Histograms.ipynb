# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
#matplotlib.style.use('ggplot') # Look Pretty
# If the above line throws an error, use plt.style.use('ggplot') instead
plt.style.use('ggplot')

# %%
student_dataset = pd.read_csv("D:\misc\edx\Programming with Python for Data Science\DAT210x\Module3\Datasets\students.data", index_col=0)

# %%
my_series = student_dataset.G3
my_dataframe = student_dataset[['G3', 'G2', 'G1']]

# %%
my_series.plot.hist(alpha=0.5) #if errors appears then delete matplotlib and then reinstall
my_dataframe.plot.hist(alpha=0.5)
plt.show()
